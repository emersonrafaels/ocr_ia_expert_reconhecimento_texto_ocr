# %% [markdown]
# # IMPORTANDO AS BIBLIOTECAS NECESSÁRIAS

# %%
import numpy as np
import argparse
import imutils
import cv2

# %%
from matplotlib import pyplot as plt

# %%
plt.rcParams["figure.figsize"] = (12, 8)

# %% [markdown]
# # DEFININDO A IMAGEM A SER UTILIZADA

# %%
args = {
    "image": r"C:\Users\Emerson\Desktop\brainIAcs\MASSA_IMAGENS\CARTAS DE FATURAMENTO\Carta5.PNG"
}

# %%
image = cv2.imread(args["image"])

# %%
plt.imshow(image)
plt.show()

# %% [markdown]
# # PRÉ PROCESSAMENTO

# %% [markdown]
# ## CONVERTENDO A IMAGEM EM GRAYSCALE

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %% [markdown]
# ## APLICANDO O THRESHOLD (LIMIAR)

# %%
val, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)

# %%
val, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)

# %% [raw]
# APLICANDO THRESHOLD OTSU, NO QUAL O VALOR DE THRESH É OBTIDO AUTOMATICAMENTE

# %%
print("VALOR DE LIMIAR: {}".format(val))
# Out:
# VALOR DE LIMIAR: 165.0

# %%
plt.imshow(thresh, cmap="gray")
plt.show()

# %% [raw]
# Observe que, como escolhemos cv2.THRESH_BINARY_INV como parâmetro, os pixels de alta intensidade são alterados para 0, enquanto os pixels circundantes de baixa intensidade tornam-se 255.

# %% [markdown]
# # ENCONTRANDO CONTORNOS
